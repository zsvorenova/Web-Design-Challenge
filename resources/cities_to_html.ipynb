# %%
import pandas as pd
import numpy as np

# %%
# reading data from csv to new plot so we do not have to run previous part again
weather_df=pd.read_csv("cities.csv")
weather_df.head()
# Out:
#        City Country    Lat     Lng  Max Temp (F)  Humidity (%)  \
# 0      hami      CN  42.80   93.45         45.91            46
# 1    albany      US  42.60  -73.97         70.00            72
# 2   mataura      NZ -46.19  168.86         64.99            61
# 3    faanui      PF -16.48 -151.75         78.85            74
# 4  augustow      PL  53.84   22.98         48.97            95
#
#    Cloudiness (%)  Wind Speed(mph)        Date
# 0               0             2.73  1603489829
# 1              83             1.99  1603489831
# 2              60             8.01  1603489833
# 3              13             8.55  1603489479
# 4              66             4.18  1603490000

# %%
# parse the Date to easier readible format
weather_df["Date"] = pd.to_datetime(weather_df["Date"], unit="s").dt.strftime("%m/%d/%Y")
weather_df.head()
# Out:
#        City Country    Lat     Lng  Max Temp (F)  Humidity (%)  \
# 0      hami      CN  42.80   93.45         45.91            46
# 1    albany      US  42.60  -73.97         70.00            72
# 2   mataura      NZ -46.19  168.86         64.99            61
# 3    faanui      PF -16.48 -151.75         78.85            74
# 4  augustow      PL  53.84   22.98         48.97            95
#
#    Cloudiness (%)  Wind Speed(mph)        Date
# 0               0             2.73  10/23/2020
# 1              83             1.99  10/23/2020
# 2              60             8.01  10/23/2020
# 3              13             8.55  10/23/2020
# 4              66             4.18  10/23/2020

# %%
print(weather_df.to_html())
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>City</th>
#       <th>Country</th>
#       <th>Lat</th>
#       <th>Lng</th>
#       <th>Max Temp (F)</th>
#       <th>Humidity (%)</th>
#       <th>Cloudiness (%)</th>
#       <th>Wind Speed(mph)</th>
#       <th>Date</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>hami</td>
#       <td>CN</td>
#       <td>42.80</td>
#       <td>93.45</td>
#       <td>45.91</td>
#       <td>46</td>
#       <td>0</td>
#       <td>2.73</td>
#       <td>10/23/2020</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>albany</td>
#       <td>US</td>
#       <td>42.60</td>
#       <td>-73.97</td>
#       <td>70.00</td>
#       <td>72</td>
#       <td>83</td>
#       <td>1.99</td>
#       <td>10/23/2020</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>mataura</td>
#       <td>NZ</td>
#       <td>-46.19</td>
#       <td>168.86</td>
# ...
